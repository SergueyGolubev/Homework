# %%
import pandas as pd
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
from pylab import rcParams

from wordcloud import WordCloud

import nltk
from nltk import word_tokenize, PorterStemmer, StanfordTokenizer
from nltk.corpus import stopwords

# %matplotlib inline  
rcParams['figure.figsize'] = 12, 18

# %% [markdown]
# First we load emails and initialize a wordcloud instmance

# %%
emails = pd.read_csv("hillary-clinton-emails/Emails.csv")

# %%
wc = WordCloud(background_color="white")

# %% [markdown]
# According to the data schema from kaggle we should use 'ExtractedBodyText' as "Attempt to only pull out the text in the body that the email sender wrote". However the interesting part can be forwarded by someone and still represents the intereset for analysis.

# %%
text = ' '.join(emails['RawText'].dropna())

# %%
wc.generate(text)
plt.imshow(wc)

# %% [markdown]
# We see some duplicates as well stopwords in this result. Now we can try to implement a standard pipline where we perform tokenization, remove stopwords and apply steaming.

# %%
porter = nltk.PorterStemmer()
customstopwords = stopwords.words('english')
customstopwords = customstopwords + ['nan','call', 'know', 'would', 'get', 'time', 'work', 'like', 'today', 
                                     'see', 'morning', 'also', 'back', 'tomorrow', 'meeting', 'think', 
                                     'good', 'want', 'could', 'working', 'well', 'fw', 'fyi', 're', 'pm', 'h',
                                     'subject',
                                     'a','about','above','across','after','again','against','all','almost',
                                     'alone','along','already','also','although','always','among','an','and',
                                     'another','any','anybody','anyone','anything','anywhere','are','area',
                                     'areas','around','as','ask','asked','asking','asks','at','away','b','back',
                                     'backed','backing','backs','be','became','because','become','becomes','been',
                                     'before','began','behind','being','beings','best','better','between','big',
                                     'both','but','by','c','came','can','cannot','case','cases','certain',
                                     'certainly','clear','clearly','come','could','d','did','differ','different',
                                     'differently','do','does','done','down','down','downed','downing','downs',
                                     'during','e','each','early','either','end','ended','ending','ends','enough',
                                     'even','evenly','ever','every','everybody','everyone','everything',
                                     'everywhere','f','face','faces','fact','facts','far','felt','few','find',
                                     'finds','first','for','four','from','full','fully','further','furthered',
                                     'furthering','furthers','g','gave','general','generally','get','gets','give',
                                     'given','gives','go','going','good','goods','got','great','greater','greatest',
                                     'group','grouped','grouping','groups','h','had','has','have','having','he','her',
                                     'here','herself','high','high','high','higher','highest','him','himself','his',
                                     'how','however','i','if','important','in','interest','interested','interesting',
                                     'interests','into','is','it','its','itself','j','just','k','keep','keeps','kind',
                                     'knew','know','known','knows','l','large','largely','last','later','latest',
                                     'least','less','let','lets','like','likely','long','longer','longest','m',
                                     'made','make','making','man','many','may','me','member','members','men',
                                     'might','more','most','mostly','mr','mrs','much','must','my','myself',
                                     'n','necessary','need','needed','needing','needs','never','new','new',
                                     'newer','newest','next','no','nobody','non','noone','not','nothing',
                                     'now','nowhere','number','numbers','o','of','off','often','old','older',
                                     'oldest','on','once','one','only','open','opened','opening','opens','or',
                                     'order','ordered','ordering','orders','other','others','our','out','over',
                                     'p','part','parted','parting','parts','per','perhaps','place','places',
                                     'point','pointed','pointing','points','possible','present','presented',
                                     'presenting','presents','problem','problems','put','puts','q','quite','r',
                                     'rather','really','right','right','room','rooms','s','said','same','saw',
                                     'say','says','second','seconds','see','seem','seemed','seeming','seems',
                                     'sees','several','shall','she','should','show','showed','showing','shows',
                                     'side','sides','since','small','smaller','smallest','so','some','somebody',
                                     'someone','something','somewhere','state','states','still','still','such',
                                     'sure','t','take','taken','than','that','the','their','them','then','there',
                                     'therefore','these','they','thing','things','think','thinks','this','those',
                                     'though','thought','thoughts','three','through','thus','to','today','together',
                                     'too','took','toward','turn','turned','turning','turns','two','u','under',
                                     'until','up','upon','us','use','used','uses','v','very','w','want',
                                     'wanted','wanting','wants','was','way','ways','we','well','wells','went','were',
                                     'what','when','where','whether','which','while','who','whole','whose','why',
                                     'will','with','within','without','work','worked','working','works','would','x',
                                     'y','year','years','yet','you','young','younger','youngest','your','yours','z']


tokens = [token for sent in nltk.sent_tokenize(text) for token in nltk.word_tokenize(sent)]
# text = nltk.Text(tokens)
words = [w.lower() for w in tokens]
wordswostop = [w for w in words if w not in customstopwords]
wordsclean = [porter.stem(w) for w in wordswostop]

# %% [markdown]
# We can compare number of tokens before and after removing stopwords

# %%
len(tokens), len(wordswostop)
# Out:
# (3665281, 2227291)

# %%
textclean = ' '.join(wordsclean)
wc.generate(textclean)
plt.imshow(wc)
plt.show()

# %% [markdown]
# As we can see we were not able to remove many duplicates. At the same time we also lost the endings and introduced additional ambiguity. Overall we cannot say the results are sugnificant better than before.
# One thing would be to compare what kind of tokens we have for duplicates. As an example we can check all occurences of 'gov' where lots of tokens have a variaty of forms including punctuation. We assume such tokens can be differently handeled in wordcloud library.

# %%
set(w for w in wordswostop if 'gov' in w and len(w)>3)
# Out:
# {"'abedinh©state.gov'",
#  "'campbelikm©state.gov'",
#  "'hanleymrgastategov'",
#  "'jilotylc©state.gov",
#  "'jilotylc©state.gov'",
#  "'jilotylc©state.govl",
#  "'russorv©state.gov'",
#  "'valmorou©state.gov",
#  "'valmorou©state.gov'",
#  '-government',
#  '-governor',
#  '.3state.gov',
#  '.gov.br/sedh',
#  '.gove.ftn',
#  '.‹suilivan1j©st.ate.gov',
#  '//blog.usaid.gov/2010/09/1000-days-partnering-to-reduce-child-undernutrition/',
#  '//blogs.abcnews.com/thenote/2010/09/gov-barbour-no-excuse-for-koran-burning-stirring-up-anti-',
#  '//blogs.state.gov',
#  '//blogs.state.gov/index.phasite/entry/1000',
#  '//democrats.senate.govicalendar/',
#  '//finance.senate.gov/press/bpress/2009press/prb062009.pdf',
#  '//fpc.state.gov/documents/organization/80250.pdf',
#  '//fpc.state.gov/documents/organizdion/80250.pctf',
#  '//frwebgate.access.gpo.gov/cgi-',
#  '//frwebgate.access.gpo.gov/cgi-bin/getdoc.cgi',
#  '//frwebgatearess.gpo.govicgi-',
#  '//frwebgge.axess.gpo.govicgi-bin/getdoc.cgi',
#  '//go.usa.gov/cim',
#  '//haiti.usembassy.gov/',
#  '//hsgac.sancie.gov/publ',
#  '//hsgac.senate.gov/public/index.cfm',
#  '//inseuters.com/articleigovernmentfilingsnews/idinwbt01137420090616',
#  '//islamabad.usembassy.gov',
#  '//islamabad.usembassy.gov/',
#  '//kaygranger.house.gov/index.cfm',
#  '//london.usembassy.gov/',
#  '//luciar.senate.gov',
#  '//lugar.senate.gov',
#  '//lugar.senate.gov/',
#  '//madrid.usembassy.gov',
#  '//mccaskill.senate.gov/pdf/061009/071907.pdf',
#  '//mccaskill.senate.gov/pdf/061009/092108.pdf',
#  '//mccaskill.senate.gov/pdf/061009/staffanalysis.pdf',
#  '//mccaskill.wnate.gov/pdf/061009/0921',
#  '//mccaskoll.senate.gov/pdf/061009/staffanalysis.pctf',
#  '//nicaragua.usembassy.gov',
#  '//oversight.houm.govkiocuments/20071002142635.pctf',
#  '//oversight.house.gov/documents/20071002142635.pdf',
#  '//ryccaskill.senate.gov/pdf/0610',
#  '//ses.state.sgov.gov',
#  '//ses.state.sgov.gov/',
#  '//ses.state.sgov.govh',
#  '//thomas.ioc.gov/cgi-bin/query/z',
#  '//travel.state.gov/passport/ppt_card/ppt_card_3926.html',
#  '//travel.state.gov/passport/ppt_cardippt_card_3921.html',
#  '//twitter.com/americagov',
#  '//www.adobe.com/opengov/',
#  '//www.america.gov/',
#  '//www.america.govist/develop-english/2010/september/20100914162252berehellek0.3766291.html',
#  '//www.cbp.gov/xp/cgov/travel/trusted_traveler/nexus_proginexus.xml',
#  '//www.defense.gov/news/newsarticle.aspx',
#  '//www.fic.nih.gov/',
#  '//www.foreignaffairs.house.gov/',
#  '//www.fsa.gov.uk',
#  '//www.fsa.gov.uk/',
#  '//www.gao.gov/new.items/d08966.pdf',
#  '//www.gao.govinetv.items/d08966.pctf',
#  '//www.intelink.gov/wiki/portal',
#  '//www.maec.gov.ma/future2009/en/defaulthtill',
#  '//www.nio.gov.uk/the-agreement',
#  '//www.nio.gov.ukithe-agreement',
#  '//www.senate.govilegislative/lis/roll_call_lists/roll_call_vote_cfm.cfm',
#  '//www.state.gov',
#  '//www.state.gov/',
#  '//www.state.gov/g/drl/rls/hrrpt/2009/wha/136116.htm',
#  '//www.state.gov/r/pa/ei/ask/secretary/117297.htm',
#  '//www.state.gov/r/pa/ei/ask/secretary/120236.htm',
#  '//www.state.gov/s/gwi/rls/rem/2009/125512.htm',
#  '//www.state.gov/secretary/rm/2009a/01/115585.htm',
#  '//www.state.gov/secretary/rm/2010/01/135519.htm',
#  '//www.state.gov/secretary/rm/2010/03/138320.htm',
#  '//www.state.gov/secretary/rm/2010/09/147512.htm',
#  '//www.state.gov/secretary/rm/2010/10/150189.htm',
#  '//www.state.gov/secretary/trvi/map/',
#  '//www.state.govh',
#  '//www.state.govk',
#  '//www.travel.state.gov/',
#  '//www.travel.state.govh',
#  '//www.usaid.gov/',
#  '//www.usaspending.gov/fpds/fpds.php',
#  '//www.usun.state.gov',
#  '//www.usun.state.gov/',
#  '//www.usun.state.govh',
#  '//www.whitehouse.gov/blog/coming-together-bringing-down-costs/',
#  '//www.whitehouse.gov/the_press_office/president-obama-to-request-50-million-to-identify-and-expand-',
#  '//www.whitehouse.govibloq/coming-togethe',
#  '000001s2.house.gov',
#  '1millscd©state.govi',
#  '`rnillscd©stategov`',
#  'abedinhpstate.gov',
#  'abedinh©state.gov',
#  'abedinh©state.gov›',
#  'abedinh©state_gov',
#  'abudhabi.mepi.state.gov',
#  'ai.e.gov',
#  'america.gov',
#  'anti-government',
#  'appro.senate.gov',
#  'astate.gov',
#  'astate.govj',
#  'badghis.government',
#  'balderstonkm©state.gov',
#  'barks-ruqqleseinstate.gov',
#  'barnes12©state.gov',
#  'burnsw3©state.gov',
#  'carlandjm©state.gov',
#  'cindy.buhlomail.house.gov',
#  'clinton.senate.gov',
#  'clinton.senate.govi',
#  'crowleypj©state.gov',
#  'dem-sec.senate.gov',
#  'democratic-message-center.senate.gov',
#  'douglaswt©state.gov',
#  'dpc.senate.gov',
#  'duboseml©state.gov',
#  'e-government',
#  'ellaticus.sonatu.gov',
#  'essenate.govi',
#  'extra-governmental',
#  'federal-government',
#  'feltmanjd©state.gov',
#  'fuchsmh©state.gov',
#  'gonzalezjs©state.gov',
#  'gordonph©state.gov',
#  "gov't",
#  'gov-',
#  'govemment',
#  'govemments',
#  'govenmen',
#  'govenunents',
#  'goverment',
#  'govern',
#  'govern-',
#  'governance',
#  'governance/making',
#  'governance—that',
#  'governed',
#  'governement',
#  'governing',
#  'government',
#  "government's",
#  'government-',
#  'government-backed',
#  'government-civil',
#  'government-controlled',
#  'government-facilitated',
#  'government-financed',
#  'government-funded',
#  'government-imposed',
#  'government-in-exile',
#  'government-long',
#  'government-opposition',
#  'government-originated',
#  'government-owned',
#  'government-paid',
#  'government-run',
#  'government-sponsored',
#  'government-to-government',
#  'government-to-people',
#  'government-wide',
#  'government.9',
#  'government.—upon',
#  'government/',
#  'governmenta',
#  'governmental',
#  'governments',
#  'governments-aspac',
#  'governments—can',
#  'governments—rather',
#  'governments•condemned',
#  'government—and',
#  'government—between',
#  'government—long',
#  'governn.1,75‘',
#  'governo',
#  'governor',
#  'governors',
#  'governorship',
#  'governorships',
#  'governos',
#  'governs',
#  'govi',
#  'goviles',
#  'govj',
#  'govnt',
#  'govt',
#  'govts',
#  'gov›',
#  'hanleylvirpstate.govi',
#  'hanleymrostate.gov',
#  'hanleymr©state.gov',
#  'herzegovina',
#  'house.gov',
#  'ilicstate.gov',
#  'imillscd©state.govi',
#  "intergov'tal",
#  'intergovern-',
#  'intergovernmental',
#  'intra-governmental',
#  'izetbegovi',
#  'jilotylc4state.gov',
#  'jilotylc©state.gov',
#  "jilotylc©state.gov'",
#  'kellyic2ostate.gov',
#  'kellyic2state.gov',
#  'klevorickcbgstate.gov',
#  'klobuchar.senate.gov',
#  'kohhh©state.gov',
#  'lautenberg.senate.gov',
#  "lautenberg.senate.gov'",
#  'lemieux.senate.gov',
#  'lewjj©state.gov',
#  'lugar.senate.gov',
#  'lugarsenate.gov',
#  'mail.house.gov',
#  'mail.house.gov1',
#  'mail.house.govi',
#  'mailhouse.gov',
#  'majorityleader.gov',
#  'mcgovern',
#  'mcgrifftlostate.gov',
#  'mchaleja©state.gov',
#  'menendez.senate.gov',
#  'mhcalejaftstate.gov',
#  'miiiscd©state.gov',
#  'mikuiski.senate.gov',
#  'mikulski.senate.gov',
#  "mikulski.senate.gov'",
#  'millsca©state.govj',
#  'millscd6state.govi',
#  'millscdastate.gov',
#  'millscdebstategov',
#  'millscdostate.gov',
#  'millscdostate.govj',
#  'millscdpstate.gov',
#  'millscdstate.gov',
#  'millscd©state.gov',
#  'millscd©state.gova',
#  'millscd©state.govi',
#  'miskosa2ostate.sgov.gov',
#  'miskosapstate.gov',
#  'mozgovaya',
#  'muscatinel©state.gov',
#  'ng.gov/f',
#  'non-government',
#  'non-governmental',
#  'nongovern-',
#  'nongovernment',
#  'nongovernmental',
#  'nonprofit/government',
#  'of-government',
#  "ofda.gov'",
#  'opsnewsticker©state.gov',
#  'organizations-governmental',
#  'organizations—governmental',
#  'pallymm©state.gov',
#  'pascualmt©state.gov',
#  'penalastate.gov',
#  'picgriffillastate.gov',
#  'pro-government',
#  'rebecca.g.ulrichamail.house.gov',
#  'reid.senate.gov',
#  'rmrmalinstate.gov',
#  'rodriguezme©state.gov',
#  'rooneym©state.gov',
#  'rossdbostate.gov',
#  'russorv©state.gov',
#  'samuelsonhfstate.gov',
#  'scwarzericpostate.gov',
#  'self-governance',
#  'self-governing',
#  'selingermupstatc.gov',
#  'sheistadjestate.gov',
#  "siate.gov'",
#  'siemerme©state.gov',
#  'slaughtera©state.gov',
#  'smithje©state.gov',
#  'spending.gov',
#  'staged-government',
#  'state.gov',
#  "state.gov'",
#  "state.gov'classified",
#  "state.gov's",
#  'state.gov1',
#  'state.gov`',
#  'state.gova',
#  'state.gove',
#  'state.govi',
#  'state.govisecretary/rm/2012/09/197654.htm',
#  'state.govj',
#  'state.govl',
#  'state.govm',
#  'state.govr',
#  'state.govs',
#  'state.govt',
#  'state.govy',
#  'state.gov°',
#  'state.gov›',
#  "state_gov'",
#  'stategov',
#  "stategov'",
#  'stategov`',
#  'stategovi',
#  'stategovl',
#  'stategovs',
#  'stategov‘',
#  'stategov›',
#  'steinbergjf33state.gov',
#  'sullivan.lifstate.govi',
#  'sullivandostate.gov',
#  'sullivanflostate.gov',
#  'sullivaniiestate.gov',
#  'sullivanijastate.gov',
#  'sullivanij©state.gov',
#  'sullivanjj©state.gov',
#  'sullivanjj©stategove',
#  'sullivanwstate.govj',
#  'sullivaralestate.gov',
#  'sulliyanjj©state.gov',
#  'tate.gov',
#  'themocrats.senate.govicalendar/',
#  'tillemanntsgstate.gov',
#  'tillemannts©state.gov',
#  'tillemnantsostate.gov',
#  'tongkwpstate.gov',
#  'tongkw©state.gov',
#  'travel.state.gov',
#  'ungoverned',
#  'university/mcgovern',
#  'usaspending.gov',
#  'v7rveerms©state.gov',
#  'valenzuelaaaastate.gov',
#  'valenzuelaaa©state.gov',
#  'valmorou©state.gov',
#  'vance2.state.gov',
#  'vance3.state.gov',
#  'vancel.state.gov',
#  'vermarrftstate.gov',
#  'vermarr©state.gov',
#  'verveerms©state.gov',
#  'vvvvw.mopea.gov.lr',
#  'w/government',
#  'well-governed',
#  'whitehouse.gov',
#  'whole-of-government',
#  'whole-ofgovernment',
#  'whorunsgov',
#  'willsrwastate.gov',
#  'woodardew26state.gov',
#  'woodardew2cestate.gov',
#  'woodardew2ostate.gov',
#  'woodardew2©state.gov',
#  'woodardew©state.gov',
#  'www.house.gov.ihanyi',
#  'www.liftliberia.gov.lr',
#  'www.state.gov',
#  'www.state.gov/g/prm',
#  'www.state.gov/s/globalfoodsecurity',
#  'www.usun.state.gov',
#  'yougov'}
